# %% [markdown]
# <a href="https://colab.research.google.com/github/1989Cristianq/modelodatos/blob/main/Proyecto_Deserci%C3%B3n_Escolar_2011_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas numpy scikit-learn xgboost lightgbm matplotlib seaborn shap geopandas openpyxl plotly
